# %% [markdown]
# <hr style="border:2px solid #808080"> </hr>
# <center><h1 style="color:#03122E;"> Álgebra Lineal Numérica IMT2111</h1></center>
# <center><h1 style="color:#173F8A;"> Capítulo 2</h3></center>
# <center><h1 style="color:#0176DE;"> Prof. Manuel A. Sánchez</h3></center>
# <hr style="border:2px solid #808080"> </hr>

# %%
import numpy as np
from numpy.linalg import norm
import matplotlib.pyplot as plt

# %% [markdown]
# ## Iteracion de Lanczos
# $$ A = Q T Q^\top $$

# %%
def Lanczos1(A, q1, TOL=1e-14, MAXITER = 100):
    '''
    Input  : A simetrica, q1, \|q1\|=`
    Output : Qk = [q1|q2|...|qk] orthonormal, Tk[k,k] = alphak, Tk[k+1,k]=Tk[k,k+1] = betak; A*Qk = Tk*Qk
    ''' 
    n, n = A.shape
    q0 = np.zeros(n)
    Qlist = []; Qlist.append(q0)
    alpha = []; beta  = []; beta.append(1.0)
    k = 0
    rk = q1.copy()
    while beta[k] >TOL and k < n:
        q = rk / beta[k]; Qlist.append(q)
        k += 1
        alphak = q.dot(A.dot(q)); alpha.append(alphak)
        rk = A.dot(q) - alphak*q - beta[k-1]*Qlist[k-1]
        betak = np.linalg.norm(rk); beta.append(betak)
    Q = np.stack(Qlist[1:], axis=1 )
    Tk = np.diag(alpha) + np.diag(beta[1:-1],-1) + np.diag(beta[1:-1],1)

    return Q, Tk, betak, k

# %% [markdown]
# ### Test 1:
# \begin{equation}
# A =
# \begin{bmatrix}
# 2& 1/\sqrt{2} & -1/\sqrt{2} \\
# 1/\sqrt{2} & 3 & 0 \\
# -1/\sqrt{2} & 0 & 1
# \end{bmatrix} =
# \begin{bmatrix}
# 1 & 0 & 0 \\
# 0 & 1/\sqrt{2} & 1/\sqrt{2}  \\
# 0 & -1/\sqrt{2} & 1/\sqrt{2}
# \end{bmatrix}
# \begin{bmatrix}
# 2 & 1 & 0 \\
# 1 & 2 & 1 \\
# 0 & 1 & 2
# \end{bmatrix}
# \begin{bmatrix}
# 1 & 0 & 0 \\
# 0 & 1/\sqrt{2} & 1/\sqrt{2}  \\
# 0 & -1/\sqrt{2} & 1/\sqrt{2}
# \end{bmatrix}^\top
# \end{equation}

# %%
A = np.array([[2.0, 1.0/np.sqrt(2.0), -1/np.sqrt(2.0)],[1.0/np.sqrt(2.0),3.0,0.0],[-1/np.sqrt(2.0), 0,1.0]])
Qk, Tk, betalast, niter = Lanczos1(A, np.array([1.0,0,0], dtype=np.float64))
print("||Qk.T A Qk - Tk|| =",np.linalg.norm(Qk.T@(A@(Qk))-Tk ))
print(" betalast = ",betalast, ",  niter : ", niter)
# Out:
# ||Qk.T A Qk - Tk|| = 1.9886408546293493e-16
#  betalast =  4.3561932445802306e-16 ,  niter :  3

# %% [markdown]
# ### Test 2:
# \begin{equation}
# A =
# \begin{bmatrix}
# 2& \sqrt{2} & -\sqrt{2} \\
# \sqrt{2} & 1 & -3 \\
# -\sqrt{2} & -3 & -1
# \end{bmatrix} =
# \begin{bmatrix}
# 1 & 0 & 0 \\
# 0 & 1/\sqrt{2} & 1/\sqrt{2}  \\
# 0 & -1/\sqrt{2} & 1/\sqrt{2}
# \end{bmatrix}
# \begin{bmatrix}
# 2 & 2 & 0 \\
# 2 & 3 & 1 \\
# 0 & 1 & -3
# \end{bmatrix}
# \begin{bmatrix}
# 1 & 0 & 0 \\
# 0 & 1/\sqrt{2} & 1/\sqrt{2}  \\
# 0 & -1/\sqrt{2} & 1/\sqrt{2}
# \end{bmatrix}^\top
# \end{equation}

# %%
A = np.array([[2.0, np.sqrt(2.0), -np.sqrt(2.0)],[np.sqrt(2.0),1.0,-3.0],[-np.sqrt(2.0), -3.0,-1.0]])
Qk, Tk, betalast, niter = Lanczos1(A, np.array([1.0,0,0], dtype=np.float64))
print("||Qk.T A Qk - Tk|| =",np.linalg.norm(Qk.T@(A@(Qk))-Tk ))
print(" betalast = ",betalast, ",  niter : ", niter)
# Out:
# ||Qk.T A Qk - Tk|| = 1.4160648549979043e-15
#  betalast =  3.3875874904095572e-15 ,  niter :  3

# %% [markdown]
# ### Test 3:
# #### Random matrix

# %%
N = 10
B = np.random.rand(N,N)
Bsym = 0.5*(B.T + B)
Qk, Tk, betalast, niter = Lanczos1(Bsym, np.array(np.eye(N)[:,0], dtype=np.float64))
print("||Qk.T A Qk - Tk|| =",np.linalg.norm(Qk.T@(Bsym@(Qk))-Tk ))
print(" betalast = ",betalast, ",  niter : ", niter)
# Out:
# ||Qk.T A Qk - Tk|| = 1.209963016028301e-07
#  betalast =  9.329276327314036e-08 ,  niter :  10

# %% [markdown]
# ## Metodo de Gradientes Conjugados (CG)
# ### version 1 como mejora de steepest descent

# %%
from numpy.linalg import norm
def SteepestDescent(A, b, x0, TOL=1e-8, MAXIT=100, print_iter=False):
    x = x0.copy()
    g = A.dot(x0) - b 
    ng = g.dot(g)
    Xlist = []
    Xlist.append(x.copy())
    niter = 0
    while np.sqrt(ng)>TOL and niter < MAXIT:
        # step length corresponding to exact line search
        mu = ng / np.dot(g, np.dot(A,g))
        x -= mu*g
        g = A.dot(x) - b
        
        ng = g.dot(g)
        #
        niter += 1
        printSD(niter,ng)
        Xlist.append(x.copy())
    return x, niter, Xlist

def printSD(iter, res):
    print(f" *** SD iteration {iter}, residual = {res:1.2e}")

# %%
def printCG(iter, res):
    print(f" *** CG iteration {iter}, residual = {res:1.2e}")
    
# Conjugate gradient first version Golub
# Algorithm 11.3.1
def ConjugateGradient_1(A, b, x0=None, MAXITER = 100, TOL=1e-8, print_iter=True):
    '''
    Input  : A s.d.p, b, x0
    Output : x sol. Ax = b
    '''
    if x0 is None: x0 = np.zeros(b.size)
    n, n = A.shape 
    xlist = [] ;xlist.append(x0)
    
    Qlist = []
    k = 0
    rk = b - A.dot(x0)
    beta0 = np.linalg.norm(rk.copy())
    alpha = []; beta = []; beta.append(beta0)
    q0 = np.zeros(n)
    while beta[k] > TOL and k < MAXITER:
        q1 = rk/beta[k]; Qlist.append(q1)
        k += 1
        alphak = q1.dot(A.dot(q1)); alpha.append(alphak)
        Tk = create_Tk(alpha, beta[1:])
        yk = np.linalg.solve(Tk, beta0*e1(k))
        xk  = x0+np.stack(Qlist, axis=1 ).dot(yk); xlist.append(xk)
        rk = (A.dot(q1) - alphak*q1) - beta[k-1]*q0
        betak = np.linalg.norm(rk); beta.append(betak)
        q0 = q1.copy()
        if  print_iter: printCG(k, betak)
    return xlist, k
    
def create_Tk(alpha,beta):
    return np.diag(alpha) + np.diag(beta,-1) + np.diag(beta,1)

def e1(dim):
    e1 = np.zeros(dim); e1[0] = 1.0
    return e1

# %% [markdown]
# ## Comparacion grafica CG vs SD

# %%
# Data 
a11 = 1.0; a22  = 0.1
A = np.array([[a11,.0],[.0,a22]]); b = np.array([0.0,.0])

# Iteracion Steepest descent
x, n, Xlist = SteepestDescent(A,b,x0=np.array([a22,1]), print_iter=False)

# Iteracion CG
xcg, niter = ConjugateGradient_1(A, b, x0=np.array([a22,1.0]), print_iter=True)
print("residual \|Ax-b\|:", np.linalg.norm(A.dot(xcg[-1])-b))
# Out:
#  *** SD iteration 1, residual = 1.34e-02
#  *** SD iteration 2, residual = 8.96e-03
#  *** SD iteration 3, residual = 6.00e-03
#  *** SD iteration 4, residual = 4.02e-03
#  *** SD iteration 5, residual = 2.69e-03
#  *** SD iteration 6, residual = 1.80e-03
#  *** SD iteration 7, residual = 1.20e-03
#  *** SD iteration 8, residual = 8.07e-04
#  *** SD iteration 9, residual = 5.40e-04
#  *** SD iteration 10, residual = 3.61e-04
#  *** SD iteration 11, residual = 2.42e-04
#  *** SD iteration 12, residual = 1.62e-04
#  *** SD iteration 13, residual = 1.08e-04
#  *** SD iteration 14, residual = 7.26e-05
#  *** SD iteration 15, residual = 4.86e-05
#  *** SD iteration 16, residual = 3.25e-05
#  *** SD iteration 17, residual = 2.18e-05
#  *** SD iteration 18, residual = 1.46e-05
#  *** SD iteration 19, residual = 9.76e-06
#  *** SD iteration 20, residual = 6.53e-06
#  *** SD iteration 21, residual = 4.37e-06
#  *** SD iteration 22, residual = 2.93e-06
#  *** SD iteration 23, residual = 1.96e-06
#  *** SD iteration 24, residual = 1.31e-06
#  *** SD iteration 25, residual = 8.78e-07
#  *** SD iteration 26, residual = 5.88e-07
#  *** SD iteration 27, residual = 3.93e-07
#  *** SD iteration 28, residual = 2.63e-07
#  *** SD iteration 29, residual = 1.76e-07
#  *** SD iteration 30, residual = 1.18e-07
#  *** SD iteration 31, residual = 7.90e-08
#  *** SD iteration 32, residual = 5.29e-08
#  *** SD iteration 33, residual = 3.54e-08
#  *** SD iteration 34, residual = 2.37e-08
#  *** SD iteration 35, residual = 1.59e-08
#  *** SD iteration 36, residual = 1.06e-08
#  *** SD iteration 37, residual = 7.11e-09
#  *** SD iteration 38, residual = 4.76e-09
#  *** SD iteration 39, residual = 3.19e-09
#  *** SD iteration 40, residual = 2.13e-09
#  *** SD iteration 41, residual = 1.43e-09
#  *** SD iteration 42, residual = 9.56e-10
#  *** SD iteration 43, residual = 6.40e-10
#  *** SD iteration 44, residual = 4.28e-10
#  *** SD iteration 45, residual = 2.87e-10
#  *** SD iteration 46, residual = 1.92e-10
#  *** SD iteration 47, residual = 1.29e-10
#  *** SD iteration 48, residual = 8.60e-11
#  *** SD iteration 49, residual = 5.76e-11
#  *** SD iteration 50, residual = 3.85e-11
#  *** SD iteration 51, residual = 2.58e-11
#  *** SD iteration 52, residual = 1.73e-11
#  *** SD iteration 53, residual = 1.16e-11
#  *** SD iteration 54, residual = 7.74e-12
#  *** SD iteration 55, residual = 5.18e-12
#  *** SD iteration 56, residual = 3.47e-12
#  *** SD iteration 57, residual = 2.32e-12
#  *** SD iteration 58, residual = 1.55e-12
#  *** SD iteration 59, residual = 1.04e-12
#  *** SD iteration 60, residual = 6.97e-13
#  *** SD iteration 61, residual = 4.66e-13
#  *** SD iteration 62, residual = 3.12e-13
#  *** SD iteration 63, residual = 2.09e-13
#  *** SD iteration 64, residual = 1.40e-13
#  *** SD iteration 65, residual = 9.36e-14
#  *** SD iteration 66, residual = 6.27e-14
#  *** SD iteration 67, residual = 4.20e-14
#  *** SD iteration 68, residual = 2.81e-14
#  *** SD iteration 69, residual = 1.88e-14
#  *** SD iteration 70, residual = 1.26e-14
#  *** SD iteration 71, residual = 8.43e-15
#  *** SD iteration 72, residual = 5.64e-15
#  *** SD iteration 73, residual = 3.78e-15
#  *** SD iteration 74, residual = 2.53e-15
#  *** SD iteration 75, residual = 1.69e-15
#  *** SD iteration 76, residual = 1.13e-15
#  *** SD iteration 77, residual = 7.58e-16
#  *** SD iteration 78, residual = 5.08e-16
#  *** SD iteration 79, residual = 3.40e-16
#  *** SD iteration 80, residual = 2.28e-16
#  *** SD iteration 81, residual = 1.52e-16
#  *** SD iteration 82, residual = 1.02e-16
#  *** SD iteration 83, residual = 6.82e-17
#  *** CG iteration 1, residual = 4.50e-01
#  *** CG iteration 2, residual = 2.29e-16
# residual \|Ax-b\|: 1.5021383168150948e-16

# %%
# funcion a minimizar
phi = lambda x: 0.5*x.dot(A.dot(x)) - x.dot(b)

# Make data.
x = np.arange(-1.2, 1.2, 0.025)
y = np.arange(-1.2, 1.2, 0.025)
X, Y = np.meshgrid(x, y)

Z = 0.5*(a11*X**2 + a22*Y**2)
fig, ax = plt.subplots(1,1, figsize=(10,10))

# puntos de Steepest descent
print(Xlist[0].dot(b))
X0 = Xlist[0]; x0 = X0[0]; y0 = X0[1]; f0 = phi(Xlist[0])
X1 = Xlist[1]; x1 = X1[0]; y1 = X1[1]; f1 = phi(Xlist[1])
X2 = Xlist[2]; x2 = X2[0]; y2 = X2[1]; f2 = phi(Xlist[2])
X3 = Xlist[3]; x3 = X3[0]; y3 = X3[1]; f3 = phi(Xlist[3])
X4 = Xlist[4]; x4 = X4[0]; y4 = X4[1]; f4 = phi(Xlist[4])
X5 = Xlist[5]; x5 = X5[0]; y5 = X5[1]; f5 = phi(Xlist[5])
X6 = Xlist[6]; x6 = X6[0]; y6 = X6[1]; f6 = phi(Xlist[6])
X7 = Xlist[7]; x7 = X7[0]; y7 = X7[1]; f7 = phi(Xlist[7])
CS = ax.contour(X,Y, Z, levels=[f7,f6,f5,f4,f3,f2,f1,f0])#,colors=['C05', 'C04', 'C03','C02', 'C01', 'C00'])
ax.clabel(CS, fontsize=9, inline=True)
ax.plot([x0,x1],[y0,y1],'k')
ax.plot([x1,x2],[y1,y2],'k')
ax.plot([x2,x3],[y2,y3],'k')
ax.plot([x3,x4],[y3,y4],'k')
ax.plot([x4,x5],[y4,y5],'k')
ax.plot([x5,x6],[y5,y6],'k')
ax.plot([x6,x7],[y6,y7],'k', label='steepest descent')
# puntos de CG
C0 = xcg[0]
C1 = xcg[1]
C2 = xcg[2]
ax.plot([C0[0],C1[0]],[C0[1],C1[1]],'r', label='conjugate gradient')
ax.plot([C1[0],C2[0]],[C1[1],C2[1]],'r')

ax.set_aspect('equal')
ax.legend()
plt.show()
# Out:
# 0.0

# %% [markdown]
# ## Test convergencia rapida
#
# Sean $I\in \mathbb R^{n\times n}$ la matriz identidad, $D\in \mathbb R^{r\times r}$ una matriz simetrica y $U\in \mathbb R^{n\times r}$ con r<n, tales que
# \begin{equation}
# A = I + U DU^\top
# \end{equation}
# es simetrica definida positiva

# %%
N = 15
r = 3
Ran = np.random.rand(r,r)
D = Ran.T + Ran
U = np.random.rand(N,r)
A = np.eye(N) + U@D@U.T
xexact = np.ones(N)
b = A.dot(xexact) 
x, niter = ConjugateGradient_1(A, b, x0 = np.zeros(N))
print("residual \|Ax-b\|:",np.linalg.norm(A.dot(x[-1])-b))
print("n iter: ", niter)
#eigenval,_  = np.linalg.eig(A)
#print(eigenval)
# Out:
#  *** CG iteration 1, residual = 3.78e-01
#  *** CG iteration 2, residual = 2.77e-01
#  *** CG iteration 3, residual = 1.49e-01
#  *** CG iteration 4, residual = 9.91e-09
# residual \|Ax-b\|: 2.0760236918259842e-10
# n iter:  4

# %% [markdown]
# ## Metodo de Gradientes Conjugados
# ### version 2 , version Lanczos

# %%
def ConjugateGradient_2(A, b,x0=None, TOL=1e-8, MAXITER = 100, print_iter=True):
    '''
    Algorithm 11.3.2: Conjugate Gradietns: Lanczos Version
    Input  : A s.d.p, b, x0
    Output : x sol. Ax = b
    '''
    if x0 is None: x0 = np.zeros(b.size)
    n, n = A.shape 
    Qlist = []
    k = 0
    xk = x0.copy()
    rk = b - A.dot(x0)
    beta0 = np.linalg.norm(rk.copy())
    alpha = []; alpha.append(0); beta = []; beta.append(beta0)
    q0 = np.zeros(n)
    d = []; d.append(0); el = []; nu = []; nu.append(0)
    c0 = np.zeros(n); clist = []; clist.append(c0)
    while beta[k] > TOL and k < MAXITER:
        q1 = rk/beta[k]; Qlist.append(q1)
        k += 1
        alphak = q1.dot(A.dot(q1)); alpha.append(alphak)
        if k == 1:
            d1 = alphak; d.append(d1)
            nu1 = beta0/d1; nu.append(nu1)
            ck = q1; clist.append(ck)
        else:
            el0 = beta[k-1]/d[k-1]; el.append(el0) 
            dk = alpha[k]-beta[k-1]*el0; d.append(dk)
            nuk = -beta[k-1]*nu[k-1]/d[k]; nu.append(nuk)
            ck = q1 - el0*clist[k-1]; clist.append(ck)
        xk += nu[k]*clist[k]
        rk = A.dot(q1) - alpha[k]*q1 - beta[k-1]*q0
        betak = np.linalg.norm(rk); beta.append(betak)
        q0 = q1.copy()
        if print_iter: printCG(k, betak)
    return xk, n

# %% [markdown]
# ## Metodo de Gradientes Conjugados
# ### version 3 , version Hestenes-Stiefel

# %%
def ConjugateGradient_3(A, b, x0 = None, TOL=1e-8, MAXIT = 100, print_iter=True):
    '''
    Algorithm 11.3.3. Conjugate Gradients: Hestenes-Stiefel Version
    Input  : A s.d.p, b, x0
    Output : x sol. Ax = b
    '''
    if x0 is None: x0 = np.zeros(b.size)
    k = 0
    r0 = b - A.dot(x0) 
    # vectors
    x = []; r = []
    x.append(x0); r.append(r0)
    while np.linalg.norm(r[k]) > TOL and k < MAXIT:
        k += 1
        if k == 1:
            pk = r0.copy()
        else:
            taukm1 = r[k-1].dot(r[k-1])/(r[k-2].dot(r[k-2]))
            pk = r[k-1]  + taukm1 * pk
        muk = r[k-1].dot(r[k-1])/(pk.dot(A.dot(pk)))
        xk = x[k-1] + muk * pk; x.append(xk)
        rk = r[k-1] - muk*A.dot(pk); r.append(rk)
        if print_iter: printCG(k, np.linalg.norm(rk))
    return x[k], k

# %%
def practicalCG(A, b, x0=None, TOL=1e-8, MAXIT=100, print_iter=True):
    '''
    Algorithm Practical Conjugate Gradients.  Section 11.3.8
    Input  : A s.d.p, b, x0
    Output : x sol. Ax = b
    '''
    if x0 is None: x0 = np.zeros(b.size)
    k = 0
    x = x0.copy()
    r = b - A.dot(x)
    rhoc = r.dot(r)
    delta = TOL*np.linalg.norm(b)
    while np.sqrt(rhoc) > delta:
        k += 1 
        if k == 1: 
            p = r.copy()
        else: 
            tau = rhoc/rhom
            p = r + tau*p
        w = A.dot(p)
        mu = rhoc/(p.dot(w))
        x += mu*p
        r -= mu*w
        rhom = rhoc.copy()
        rhoc = r.dot(r)
        if print_iter: printCG(k, np.sqrt(rhoc))
    return x, k

# %% [markdown]
# ## Ejemplo 1:
# \begin{equation*} A = \left(\begin{array}{cc} 2&-1\\-1&2\end{array}\right), \quad b = \left( \begin{array}{c} 1\\0 \end{array}\right) \end{equation*}

# %%
# Example 1
A = np.array([[2.0,-1.0],[-1.0,2.0]], dtype=np.float64) 
b = np.array([1.0,0.0], dtype=np.float64)

print(" Conjugate Gradients version 1 \n")
x1,n1 = ConjugateGradient_1(A,b)
print(" Conjugate Gradients version 2 \n")
x2,n2 = ConjugateGradient_2(A,b)
print(" Conjugate Gradients version 3 \n")
x3,n3 = ConjugateGradient_3(A,b)
print(" Practical Conjugate Gradients\n")
x4,n4 = practicalCG(A,b)
x4
# Out:
#  Conjugate Gradients version 1
#
#  *** CG iteration 1, residual = 1.00e+00
#  *** CG iteration 2, residual = 0.00e+00
#  Conjugate Gradients version 2
#
#  *** CG iteration 1, residual = 1.00e+00
#  *** CG iteration 2, residual = 0.00e+00
#  Conjugate Gradients version 3
#
#  *** CG iteration 1, residual = 5.00e-01
#  *** CG iteration 2, residual = 0.00e+00
#  Practical Conjugate Gradients
#
#  *** CG iteration 1, residual = 5.00e-01
#  *** CG iteration 2, residual = 0.00e+00
# array([0.66666667, 0.33333333])

# %% [markdown]
# Ejemplo 2:
# \begin{equation*} A = \left(\begin{array}{ccc} 5&1&1\\1&5&-1 \\ 1&-1&5\end{array}\right), \quad b = \left( \begin{array}{c} 4\\2\\-4 \end{array}\right) \end{equation*}

# %%
# Example 2
A = np.array([[5,1,1],[1,5,-1],[1,-1,5]], dtype=np.float64) 
b = np.array([4,2,-4], dtype=np.float64)

print(" Conjugate Gradients version 1 \n")
x1,n1 = ConjugateGradient_1(A,b)
print(" Conjugate Gradients version 2 \n")
x2,n2 = ConjugateGradient_2(A,b)
print(" Conjugate Gradients version 3 \n")
x3,n3 = ConjugateGradient_3(A,b)
print(" Practical Conjugate Gradients\n")
x4,n4 = practicalCG(A,b)
# Out:
#  Conjugate Gradients version 1
#
#  *** CG iteration 1, residual = 1.41e+00
#  *** CG iteration 2, residual = 7.36e-16
#  Conjugate Gradients version 2
#
#  *** CG iteration 1, residual = 1.41e+00
#  *** CG iteration 2, residual = 7.36e-16
#  Conjugate Gradients version 3
#
#  *** CG iteration 1, residual = 1.70e+00
#  *** CG iteration 2, residual = 7.63e-16
#  Practical Conjugate Gradients
#
#  *** CG iteration 1, residual = 1.70e+00
#  *** CG iteration 2, residual = 7.63e-16

# %% [markdown]
# ## Test Gradientes Conjugados
#
# $$
# A = I_{m} \otimes C_1 + C_2 \otimes I_{m},\quad
# C_{1}
# =
# \begin{bmatrix}
# c      &     a  &      0 & \ldots & 0     \\
# a      &     c  &      a & \ddots & \vdots\\
# 0      & \ddots & \ddots & \ddots & 0     \\
# \vdots & \ddots & a      & c      & a     \\
# 0      & \ldots & 0      & a      & c
# \end{bmatrix}, \quad
# C_{2}
# =
# \begin{bmatrix}
# c      &     b  &      0 & \ldots & 0     \\
# b      &     c  &      b & \ddots & \vdots\\
# 0      & \ddots & \ddots & \ddots & 0     \\
# \vdots & \ddots & b      & c      & b     \\
# 0      & \ldots & 0      & b      & c
# \end{bmatrix}
# $$
#
# 1. Test con numero de condicion acotado (<9): $a= 1/9,\,b = 1/0,\, c = 5/18$.
#
# 2. Test con numero de condicion no acotado : $a= -1,\,b = -1,\, c = 2$.

# %%
import pandas as pd

# %%
def testproblem(num, m):
    if num == 1:
    # Poisson matrix
        a = -1;
        b = a;
        c = 2;
    elif num == 2:
    # Averaging problem
        a = 1.0/9.0;
        b = a;
        c = 5.0/18.0;
    # end 
    C1 = c*np.diag(np.ones(m),0)+a*np.diag(np.ones(m-1),-1)+a*np.diag(np.ones(m-1),1);
    C2 = c*np.diag(np.ones(m),0)+b*np.diag(np.ones(m-1),-1)+b*np.diag(np.ones(m-1),1)
    A = np.kron(np.eye(m),C1) + np.kron(C2, np.eye(m))
    bvector = np.random.rand(m*m)
    return A, bvector

# %%
A, b = testproblem(num = 1, m=2)
print(A)
# Out:
# [[ 4. -1. -1. -0.]
#  [-1.  4. -0. -1.]
#  [-1. -0.  4. -1.]
#  [-0. -1. -1.  4.]]

# %%
# Test: Averaging
kappa2 = np.zeros(5)
nn2 =np.zeros(5, dtype=np.int64)
M2 = [5,10,20,40,80]
for m in range(len(M)):
    A, b = testproblem(2, M2[m])
    x,nn2[m] = practicalCG(A,b, MAXIT=1000)
    kappa2[m] = np.linalg.cond(A)
# print("m = ", M)
# print("Condition number: ", kappa) # <=9
# print("number ot iterations:", nn)
# Out:
#  *** CG iteration 1, residual = 7.67e-01
#  *** CG iteration 2, residual = 4.42e-01
#  *** CG iteration 3, residual = 1.86e-01
#  *** CG iteration 4, residual = 7.08e-02
#  *** CG iteration 5, residual = 2.55e-02
#  *** CG iteration 6, residual = 8.12e-03
#  *** CG iteration 7, residual = 2.66e-03
#  *** CG iteration 8, residual = 5.86e-04
#  *** CG iteration 9, residual = 8.66e-05
#  *** CG iteration 10, residual = 2.63e-05
#  *** CG iteration 11, residual = 3.65e-06
#  *** CG iteration 12, residual = 6.41e-07
#  *** CG iteration 13, residual = 1.41e-18
#  *** CG iteration 1, residual = 1.37e+00
#  *** CG iteration 2, residual = 7.17e-01
#  *** CG iteration 3, residual = 3.69e-01
#  *** CG iteration 4, residual = 1.80e-01
#  *** CG iteration 5, residual = 8.92e-02
#  *** CG iteration 6, residual = 4.35e-02
#  *** CG iteration 7, residual = 1.91e-02
#  *** CG iteration 8, residual = 7.91e-03
#  *** CG iteration 9, residual = 3.84e-03
#  *** CG iteration 10, residual = 1.94e-03
#  *** CG iteration 11, residual = 8.35e-04
#  *** CG iteration 12, residual = 3.35e-04
#  *** CG iteration 13, residual = 1.55e-04
#  *** CG iteration 14, residual = 6.64e-05
#  *** CG iteration 15, residual = 2.72e-05
#  *** CG iteration 16, residual = 1.24e-05
#  *** CG iteration 17, residual = 4.36e-06
#  *** CG iteration 18, residual = 1.24e-06
#  *** CG iteration 19, residual = 5.56e-07
#  *** CG iteration 20, residual = 2.63e-07
#  *** CG iteration 21, residual = 8.48e-08
#  *** CG iteration 22, residual = 2.91e-08
#  *** CG iteration 1, residual = 2.85e+00
#  *** CG iteration 2, residual = 1.41e+00
#  *** CG iteration 3, residual = 7.81e-01
#  *** CG iteration 4, residual = 4.09e-01
#  *** CG iteration 5, residual = 2.10e-01
#  *** CG iteration 6, residual = 1.07e-01
#  *** CG iteration 7, residual = 5.20e-02
#  *** CG iteration 8, residual = 2.41e-02
#  *** CG iteration 9, residual = 1.08e-02
#  *** CG iteration 10, residual = 5.34e-03
#  *** CG iteration 11, residual = 2.74e-03
#  *** CG iteration 12, residual = 1.37e-03
#  *** CG iteration 13, residual = 6.83e-04
#  *** CG iteration 14, residual = 3.09e-04
#  *** CG iteration 15, residual = 1.51e-04
#  *** CG iteration 16, residual = 8.00e-05
#  *** CG iteration 17, residual = 3.86e-05
#  *** CG iteration 18, residual = 1.96e-05
#  *** CG iteration 19, residual = 8.84e-06
#  *** CG iteration 20, residual = 4.21e-06
#  *** CG iteration 21, residual = 2.02e-06
#  *** CG iteration 22, residual = 9.01e-07
#  *** CG iteration 23, residual = 3.98e-07
#  *** CG iteration 24, residual = 1.91e-07
#  *** CG iteration 25, residual = 9.38e-08
#  *** CG iteration 1, residual = 5.63e+00
#  *** CG iteration 2, residual = 2.42e+00
#  *** CG iteration 3, residual = 1.32e+00
#  *** CG iteration 4, residual = 6.29e-01
#  *** CG iteration 5, residual = 3.18e-01
#  *** CG iteration 6, residual = 1.59e-01
#  *** CG iteration 7, residual = 8.13e-02
#  *** CG iteration 8, residual = 3.83e-02
#  *** CG iteration 9, residual = 1.87e-02
#  *** CG iteration 10, residual = 9.40e-03
#  *** CG iteration 11, residual = 4.80e-03
#  *** CG iteration 12, residual = 2.46e-03
#  *** CG iteration 13, residual = 1.21e-03
#  *** CG iteration 14, residual = 6.01e-04
#  *** CG iteration 15, residual = 2.94e-04
#  *** CG iteration 16, residual = 1.41e-04
#  *** CG iteration 17, residual = 7.18e-05
#  *** CG iteration 18, residual = 3.61e-05
#  *** CG iteration 19, residual = 1.79e-05
#  *** CG iteration 20, residual = 8.89e-06
#  *** CG iteration 21, residual = 4.35e-06
#  *** CG iteration 22, residual = 2.13e-06
#  *** CG iteration 23, residual = 1.08e-06
#  *** CG iteration 24, residual = 5.33e-07
#  *** CG iteration 25, residual = 2.61e-07
#  *** CG iteration 26, residual = 1.31e-07
#  *** CG iteration 1, residual = 1.17e+01
#  *** CG iteration 2, residual = 5.28e+00
#  *** CG iteration 3, residual = 2.79e+00
#  *** CG iteration 4, residual = 1.40e+00
#  *** CG iteration 5, residual = 7.28e-01
#  *** CG iteration 6, residual = 3.68e-01
#  *** CG iteration 7, residual = 1.82e-01
#  *** CG iteration 8, residual = 8.98e-02
#  *** CG iteration 9, residual = 4.58e-02
#  *** CG iteration 10, residual = 2.30e-02
#  *** CG iteration 11, residual = 1.12e-02
#  *** CG iteration 12, residual = 5.51e-03
#  *** CG iteration 13, residual = 2.73e-03
#  *** CG iteration 14, residual = 1.40e-03
#  *** CG iteration 15, residual = 7.08e-04
#  *** CG iteration 16, residual = 3.49e-04
#  *** CG iteration 17, residual = 1.73e-04
#  *** CG iteration 18, residual = 8.66e-05
#  *** CG iteration 19, residual = 4.31e-05
#  *** CG iteration 20, residual = 2.17e-05
#  *** CG iteration 21, residual = 1.11e-05
#  *** CG iteration 22, residual = 5.43e-06
#  *** CG iteration 23, residual = 2.62e-06
#  *** CG iteration 24, residual = 1.29e-06
#  *** CG iteration 25, residual = 6.46e-07
#  *** CG iteration 26, residual = 3.22e-07

# %%
tab1 = pd.DataFrame({'m':M2, 'Matrix dim':np.square(M2), 'Condition number':kappa2, 'number of CG iterations': nn2})
tab1 = tab1.style.set_caption('Ejemplo con numero de condicion acotado')
tab1
# Out:
# <style type="text/css">
# </style>
# <table id="T_a7bbb">
#   <caption>Ejemplo con numero de condicion acotado</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a7bbb_level0_col0" class="col_heading level0 col0" >m</th>
#       <th id="T_a7bbb_level0_col1" class="col_heading level0 col1" >Matrix dim</th>
#       <th id="T_a7bbb_level0_col2" class="col_heading level0 col2" >Condition number</th>
#       <th id="T_a7bbb_level0_col3" class="col_heading level0 col3" >number of CG iterations</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7bbb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a7bbb_row0_col0" class="data row0 col0" >5</td>
#       <td id="T_a7bbb_row0_col1" class="data row0 col1" >25</td>
#       <td id="T_a7bbb_row0_col2" class="data row0 col2" >5.510847</td>
#       <td id="T_a7bbb_row0_col3" class="data row0 col3" >13</td>
#     </tr>
#     <tr>
#       <th id="T_a7bbb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a7bbb_row1_col0" class="data row1 col0" >10</td>
#       <td id="T_a7bbb_row1_col1" class="data row1 col1" >100</td>
#       <td id="T_a7bbb_row1_col2" class="data row1 col2" >7.605644</td>
#       <td id="T_a7bbb_row1_col3" class="data row1 col3" >22</td>
#     </tr>
#     <tr>
#       <th id="T_a7bbb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a7bbb_row2_col0" class="data row2 col0" >20</td>
#       <td id="T_a7bbb_row2_col1" class="data row2 col1" >400</td>
#       <td id="T_a7bbb_row2_col2" class="data row2 col2" >8.572340</td>
#       <td id="T_a7bbb_row2_col3" class="data row2 col3" >25</td>
#     </tr>
#     <tr>
#       <th id="T_a7bbb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a7bbb_row3_col0" class="data row3 col0" >40</td>
#       <td id="T_a7bbb_row3_col1" class="data row3 col1" >1600</td>
#       <td id="T_a7bbb_row3_col2" class="data row3 col2" >8.883994</td>
#       <td id="T_a7bbb_row3_col3" class="data row3 col3" >26</td>
#     </tr>
#     <tr>
#       <th id="T_a7bbb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a7bbb_row4_col0" class="data row4 col0" >80</td>
#       <td id="T_a7bbb_row4_col1" class="data row4 col1" >6400</td>
#       <td id="T_a7bbb_row4_col2" class="data row4 col2" >8.970008</td>
#       <td id="T_a7bbb_row4_col3" class="data row4 col3" >26</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Test: Poisson
kappa1 = np.zeros(5)
nn1 =np.zeros(5, dtype=np.int64)
M1 = [5,10,20,40,80]
for m in range(len(M1)):
    A, b = testproblem(1, M1[m])
    x,nn1[m] = practicalCG(A,b, MAXIT=1000)
    kappa1[m] = np.linalg.cond(A)
# print("m = ", M);
# print("Condition number: ", kappa); # O(n) =O(m*m)
# print("number ot iterations:", nn);
# Out:
#  *** CG iteration 1, residual = 3.14e+00
#  *** CG iteration 2, residual = 1.94e+00
#  *** CG iteration 3, residual = 8.81e-01
#  *** CG iteration 4, residual = 3.51e-01
#  *** CG iteration 5, residual = 1.41e-01
#  *** CG iteration 6, residual = 6.68e-02
#  *** CG iteration 7, residual = 3.48e-02
#  *** CG iteration 8, residual = 9.28e-03
#  *** CG iteration 9, residual = 2.18e-03
#  *** CG iteration 10, residual = 9.28e-04
#  *** CG iteration 11, residual = 1.65e-04
#  *** CG iteration 12, residual = 3.10e-05
#  *** CG iteration 13, residual = 6.69e-17
#  *** CG iteration 1, residual = 9.02e+00
#  *** CG iteration 2, residual = 7.99e+00
#  *** CG iteration 3, residual = 6.24e+00
#  *** CG iteration 4, residual = 5.59e+00
#  *** CG iteration 5, residual = 4.11e+00
#  *** CG iteration 6, residual = 2.76e+00
#  *** CG iteration 7, residual = 1.37e+00
#  *** CG iteration 8, residual = 7.02e-01
#  *** CG iteration 9, residual = 4.06e-01
#  *** CG iteration 10, residual = 3.44e-01
#  *** CG iteration 11, residual = 2.63e-01
#  *** CG iteration 12, residual = 1.67e-01
#  *** CG iteration 13, residual = 1.12e-01
#  *** CG iteration 14, residual = 6.16e-02
#  *** CG iteration 15, residual = 2.98e-02
#  *** CG iteration 16, residual = 1.48e-02
#  *** CG iteration 17, residual = 9.97e-03
#  *** CG iteration 18, residual = 4.78e-03
#  *** CG iteration 19, residual = 2.43e-03
#  *** CG iteration 20, residual = 2.17e-03
#  *** CG iteration 21, residual = 1.00e-03
#  *** CG iteration 22, residual = 4.05e-04
#  *** CG iteration 23, residual = 2.04e-04
#  *** CG iteration 24, residual = 9.12e-05
#  *** CG iteration 25, residual = 4.14e-05
#  *** CG iteration 26, residual = 1.45e-05
#  *** CG iteration 27, residual = 5.52e-06
#  *** CG iteration 28, residual = 2.01e-06
#  *** CG iteration 29, residual = 7.20e-07
#  *** CG iteration 30, residual = 3.44e-07
#  *** CG iteration 31, residual = 1.10e-07
#  *** CG iteration 32, residual = 3.35e-08
#  *** CG iteration 1, residual = 1.92e+01
#  *** CG iteration 2, residual = 2.64e+01
#  *** CG iteration 3, residual = 2.31e+01
#  *** CG iteration 4, residual = 2.09e+01
#  *** CG iteration 5, residual = 1.84e+01
#  *** CG iteration 6, residual = 1.69e+01
#  *** CG iteration 7, residual = 1.37e+01
#  *** CG iteration 8, residual = 1.21e+01
#  *** CG iteration 9, residual = 1.07e+01
#  *** CG iteration 10, residual = 8.39e+00
#  *** CG iteration 11, residual = 6.73e+00
#  *** CG iteration 12, residual = 5.64e+00
#  *** CG iteration 13, residual = 4.08e+00
#  *** CG iteration 14, residual = 2.44e+00
#  *** CG iteration 15, residual = 1.41e+00
#  *** CG iteration 16, residual = 8.45e-01
#  *** CG iteration 17, residual = 6.45e-01
#  *** CG iteration 18, residual = 6.18e-01
#  *** CG iteration 19, residual = 5.61e-01
#  *** CG iteration 20, residual = 4.49e-01
#  *** CG iteration 21, residual = 3.89e-01
#  *** CG iteration 22, residual = 3.63e-01
#  *** CG iteration 23, residual = 2.99e-01
#  *** CG iteration 24, residual = 2.49e-01
#  *** CG iteration 25, residual = 1.93e-01
#  *** CG iteration 26, residual = 1.44e-01
#  *** CG iteration 27, residual = 9.49e-02
#  *** CG iteration 28, residual = 6.21e-02
#  *** CG iteration 29, residual = 3.85e-02
#  *** CG iteration 30, residual = 2.24e-02
#  *** CG iteration 31, residual = 1.56e-02
#  *** CG iteration 32, residual = 1.39e-02
#  *** CG iteration 33, residual = 1.14e-02
#  *** CG iteration 34, residual = 8.11e-03
#  *** CG iteration 35, residual = 5.20e-03
#  *** CG iteration 36, residual = 3.31e-03
#  *** CG iteration 37, residual = 2.01e-03
#  *** CG iteration 38, residual = 1.37e-03
#  *** CG iteration 39, residual = 1.13e-03
#  *** CG iteration 40, residual = 1.08e-03
#  *** CG iteration 41, residual = 9.08e-04
#  *** CG iteration 42, residual = 7.03e-04
#  *** CG iteration 43, residual = 4.78e-04
#  *** CG iteration 44, residual = 3.35e-04
#  *** CG iteration 45, residual = 2.34e-04
#  *** CG iteration 46, residual = 1.76e-04
#  *** CG iteration 47, residual = 1.36e-04
#  *** CG iteration 48, residual = 9.66e-05
#  *** CG iteration 49, residual = 5.41e-05
#  *** CG iteration 50, residual = 2.98e-05
#  *** CG iteration 51, residual = 1.85e-05
#  *** CG iteration 52, residual = 1.06e-05
#  *** CG iteration 53, residual = 6.61e-06
#  *** CG iteration 54, residual = 5.13e-06
#  *** CG iteration 55, residual = 3.59e-06
#  *** CG iteration 56, residual = 2.45e-06
#  *** CG iteration 57, residual = 1.50e-06
#  *** CG iteration 58, residual = 9.04e-07
#  *** CG iteration 59, residual = 5.32e-07
#  *** CG iteration 60, residual = 3.12e-07
#  *** CG iteration 61, residual = 1.86e-07
#  *** CG iteration 62, residual = 1.13e-07
#  *** CG iteration 1, residual = 4.25e+01
#  *** CG iteration 2, residual = 7.00e+01
#  *** CG iteration 3, residual = 7.08e+01
#  *** CG iteration 4, residual = 6.78e+01
#  *** CG iteration 5, residual = 6.43e+01
#  *** CG iteration 6, residual = 5.94e+01
#  *** CG iteration 7, residual = 5.43e+01
#  *** CG iteration 8, residual = 5.25e+01
#  *** CG iteration 9, residual = 5.02e+01
#  *** CG iteration 10, residual = 4.87e+01
#  *** CG iteration 11, residual = 4.52e+01
#  *** CG iteration 12, residual = 4.16e+01
#  *** CG iteration 13, residual = 3.98e+01
#  *** CG iteration 14, residual = 3.75e+01
#  *** CG iteration 15, residual = 3.45e+01
#  *** CG iteration 16, residual = 3.26e+01
#  *** CG iteration 17, residual = 3.06e+01
#  *** CG iteration 18, residual = 2.71e+01
#  *** CG iteration 19, residual = 2.41e+01
#  *** CG iteration 20, residual = 2.19e+01
#  *** CG iteration 21, residual = 1.89e+01
#  *** CG iteration 22, residual = 1.76e+01
#  *** CG iteration 23, residual = 1.56e+01
#  *** CG iteration 24, residual = 1.29e+01
#  *** CG iteration 25, residual = 1.09e+01
#  *** CG iteration 26, residual = 8.68e+00
#  *** CG iteration 27, residual = 6.85e+00
#  *** CG iteration 28, residual = 5.06e+00
#  *** CG iteration 29, residual = 3.33e+00
#  *** CG iteration 30, residual = 2.29e+00
#  *** CG iteration 31, residual = 1.84e+00
#  *** CG iteration 32, residual = 1.81e+00
#  *** CG iteration 33, residual = 1.80e+00
#  *** CG iteration 34, residual = 1.51e+00
#  *** CG iteration 35, residual = 1.18e+00
#  *** CG iteration 36, residual = 9.90e-01
#  *** CG iteration 37, residual = 8.01e-01
#  *** CG iteration 38, residual = 6.17e-01
#  *** CG iteration 39, residual = 5.08e-01
#  *** CG iteration 40, residual = 4.08e-01
#  *** CG iteration 41, residual = 3.50e-01
#  *** CG iteration 42, residual = 3.32e-01
#  *** CG iteration 43, residual = 2.89e-01
#  *** CG iteration 44, residual = 2.48e-01
#  *** CG iteration 45, residual = 2.16e-01
#  *** CG iteration 46, residual = 2.04e-01
#  *** CG iteration 47, residual = 2.08e-01
#  *** CG iteration 48, residual = 2.09e-01
#  *** CG iteration 49, residual = 2.06e-01
#  *** CG iteration 50, residual = 2.08e-01
#  *** CG iteration 51, residual = 2.08e-01
#  *** CG iteration 52, residual = 1.87e-01
#  *** CG iteration 53, residual = 1.64e-01
#  *** CG iteration 54, residual = 1.34e-01
#  *** CG iteration 55, residual = 1.09e-01
#  *** CG iteration 56, residual = 8.32e-02
#  *** CG iteration 57, residual = 5.72e-02
#  *** CG iteration 58, residual = 4.21e-02
#  *** CG iteration 59, residual = 3.38e-02
#  *** CG iteration 60, residual = 2.96e-02
#  *** CG iteration 61, residual = 2.84e-02
#  *** CG iteration 62, residual = 2.69e-02
#  *** CG iteration 63, residual = 2.42e-02
#  *** CG iteration 64, residual = 2.35e-02
#  *** CG iteration 65, residual = 2.32e-02
#  *** CG iteration 66, residual = 2.11e-02
#  *** CG iteration 67, residual = 1.81e-02
#  *** CG iteration 68, residual = 1.50e-02
#  *** CG iteration 69, residual = 1.23e-02
#  *** CG iteration 70, residual = 1.04e-02
#  *** CG iteration 71, residual = 8.96e-03
#  *** CG iteration 72, residual = 7.14e-03
#  *** CG iteration 73, residual = 5.85e-03
#  *** CG iteration 74, residual = 5.12e-03
#  *** CG iteration 75, residual = 4.38e-03
#  *** CG iteration 76, residual = 3.92e-03
#  *** CG iteration 77, residual = 3.81e-03
#  *** CG iteration 78, residual = 3.57e-03
#  *** CG iteration 79, residual = 3.43e-03
#  *** CG iteration 80, residual = 3.03e-03
#  *** CG iteration 81, residual = 2.26e-03
#  *** CG iteration 82, residual = 1.97e-03
#  *** CG iteration 83, residual = 1.60e-03
#  *** CG iteration 84, residual = 1.22e-03
#  *** CG iteration 85, residual = 8.62e-04
#  *** CG iteration 86, residual = 6.23e-04
#  *** CG iteration 87, residual = 5.07e-04
#  *** CG iteration 88, residual = 4.60e-04
#  *** CG iteration 89, residual = 4.12e-04
#  *** CG iteration 90, residual = 3.54e-04
#  *** CG iteration 91, residual = 3.03e-04
#  *** CG iteration 92, residual = 2.49e-04
#  *** CG iteration 93, residual = 2.13e-04
#  *** CG iteration 94, residual = 1.80e-04
#  *** CG iteration 95, residual = 1.45e-04
#  *** CG iteration 96, residual = 1.13e-04
#  *** CG iteration 97, residual = 8.93e-05
#  *** CG iteration 98, residual = 6.92e-05
#  *** CG iteration 99, residual = 5.44e-05
#  *** CG iteration 100, residual = 4.29e-05
#  *** CG iteration 101, residual = 3.43e-05
#  *** CG iteration 102, residual = 2.64e-05
#  *** CG iteration 103, residual = 2.04e-05
#  *** CG iteration 104, residual = 1.65e-05
#  *** CG iteration 105, residual = 1.30e-05
#  *** CG iteration 106, residual = 1.02e-05
#  *** CG iteration 107, residual = 8.29e-06
#  *** CG iteration 108, residual = 6.95e-06
#  *** CG iteration 109, residual = 5.83e-06
#  *** CG iteration 110, residual = 5.23e-06
#  *** CG iteration 111, residual = 4.30e-06
#  *** CG iteration 112, residual = 3.23e-06
#  *** CG iteration 113, residual = 2.29e-06
#  *** CG iteration 114, residual = 1.69e-06
#  *** CG iteration 115, residual = 1.35e-06
#  *** CG iteration 116, residual = 1.18e-06
#  *** CG iteration 117, residual = 1.04e-06
#  *** CG iteration 118, residual = 8.19e-07
#  *** CG iteration 119, residual = 5.79e-07
#  *** CG iteration 120, residual = 4.14e-07
#  *** CG iteration 121, residual = 3.15e-07
#  *** CG iteration 122, residual = 2.54e-07
#  *** CG iteration 123, residual = 2.14e-07
#  *** CG iteration 1, residual = 8.88e+01
#  *** CG iteration 2, residual = 1.70e+02
#  *** CG iteration 3, residual = 2.07e+02
#  *** CG iteration 4, residual = 2.12e+02
#  *** CG iteration 5, residual = 1.99e+02
#  *** CG iteration 6, residual = 1.96e+02
#  *** CG iteration 7, residual = 1.92e+02
#  *** CG iteration 8, residual = 1.89e+02
#  *** CG iteration 9, residual = 1.84e+02
#  *** CG iteration 10, residual = 1.77e+02
#  *** CG iteration 11, residual = 1.67e+02
#  *** CG iteration 12, residual = 1.61e+02
#  *** CG iteration 13, residual = 1.54e+02
#  *** CG iteration 14, residual = 1.54e+02
#  *** CG iteration 15, residual = 1.53e+02
#  *** CG iteration 16, residual = 1.50e+02
#  *** CG iteration 17, residual = 1.47e+02
#  *** CG iteration 18, residual = 1.40e+02
#  *** CG iteration 19, residual = 1.36e+02
#  *** CG iteration 20, residual = 1.32e+02
#  *** CG iteration 21, residual = 1.31e+02
#  *** CG iteration 22, residual = 1.28e+02
#  *** CG iteration 23, residual = 1.19e+02
#  *** CG iteration 24, residual = 1.14e+02
#  *** CG iteration 25, residual = 1.10e+02
#  *** CG iteration 26, residual = 1.07e+02
#  *** CG iteration 27, residual = 1.02e+02
#  *** CG iteration 28, residual = 9.80e+01
#  *** CG iteration 29, residual = 9.37e+01
#  *** CG iteration 30, residual = 9.10e+01
#  *** CG iteration 31, residual = 8.70e+01
#  *** CG iteration 32, residual = 8.46e+01
#  *** CG iteration 33, residual = 8.14e+01
#  *** CG iteration 34, residual = 7.72e+01
#  *** CG iteration 35, residual = 7.31e+01
#  *** CG iteration 36, residual = 6.97e+01
#  *** CG iteration 37, residual = 6.60e+01
#  *** CG iteration 38, residual = 6.22e+01
#  *** CG iteration 39, residual = 6.02e+01
#  *** CG iteration 40, residual = 5.84e+01
#  *** CG iteration 41, residual = 5.48e+01
#  *** CG iteration 42, residual = 5.13e+01
#  *** CG iteration 43, residual = 4.81e+01
#  *** CG iteration 44, residual = 4.51e+01
#  *** CG iteration 45, residual = 4.23e+01
#  *** CG iteration 46, residual = 3.92e+01
#  *** CG iteration 47, residual = 3.58e+01
#  *** CG iteration 48, residual = 3.15e+01
#  *** CG iteration 49, residual = 2.81e+01
#  *** CG iteration 50, residual = 2.53e+01
#  *** CG iteration 51, residual = 2.32e+01
#  *** CG iteration 52, residual = 2.09e+01
#  *** CG iteration 53, residual = 1.79e+01
#  *** CG iteration 54, residual = 1.51e+01
#  *** CG iteration 55, residual = 1.22e+01
#  *** CG iteration 56, residual = 9.56e+00
#  *** CG iteration 57, residual = 7.40e+00
#  *** CG iteration 58, residual = 5.73e+00
#  *** CG iteration 59, residual = 4.66e+00
#  *** CG iteration 60, residual = 4.37e+00
#  *** CG iteration 61, residual = 4.66e+00
#  *** CG iteration 62, residual = 5.09e+00
#  *** CG iteration 63, residual = 4.86e+00
#  *** CG iteration 64, residual = 4.19e+00
#  *** CG iteration 65, residual = 3.88e+00
#  *** CG iteration 66, residual = 3.72e+00
#  *** CG iteration 67, residual = 3.35e+00
#  *** CG iteration 68, residual = 2.97e+00
#  *** CG iteration 69, residual = 2.73e+00
#  *** CG iteration 70, residual = 2.47e+00
#  *** CG iteration 71, residual = 2.21e+00
#  *** CG iteration 72, residual = 1.94e+00
#  *** CG iteration 73, residual = 1.72e+00
#  *** CG iteration 74, residual = 1.54e+00
#  *** CG iteration 75, residual = 1.37e+00
#  *** CG iteration 76, residual = 1.22e+00
#  *** CG iteration 77, residual = 1.12e+00
#  *** CG iteration 78, residual = 1.05e+00
#  *** CG iteration 79, residual = 9.78e-01
#  *** CG iteration 80, residual = 9.16e-01
#  *** CG iteration 81, residual = 8.56e-01
#  *** CG iteration 82, residual = 8.12e-01
#  *** CG iteration 83, residual = 7.70e-01
#  *** CG iteration 84, residual = 7.17e-01
#  *** CG iteration 85, residual = 6.54e-01
#  *** CG iteration 86, residual = 5.93e-01
#  *** CG iteration 87, residual = 5.43e-01
#  *** CG iteration 88, residual = 5.07e-01
#  *** CG iteration 89, residual = 4.83e-01
#  *** CG iteration 90, residual = 4.83e-01
#  *** CG iteration 91, residual = 4.85e-01
#  *** CG iteration 92, residual = 4.85e-01
#  *** CG iteration 93, residual = 4.76e-01
#  *** CG iteration 94, residual = 4.72e-01
#  *** CG iteration 95, residual = 4.74e-01
#  *** CG iteration 96, residual = 4.72e-01
#  *** CG iteration 97, residual = 4.75e-01
#  *** CG iteration 98, residual = 4.78e-01
#  *** CG iteration 99, residual = 4.86e-01
#  *** CG iteration 100, residual = 4.83e-01
#  *** CG iteration 101, residual = 4.82e-01
#  *** CG iteration 102, residual = 4.70e-01
#  *** CG iteration 103, residual = 4.47e-01
#  *** CG iteration 104, residual = 4.20e-01
#  *** CG iteration 105, residual = 4.02e-01
#  *** CG iteration 106, residual = 3.74e-01
#  *** CG iteration 107, residual = 3.28e-01
#  *** CG iteration 108, residual = 2.83e-01
#  *** CG iteration 109, residual = 2.45e-01
#  *** CG iteration 110, residual = 2.07e-01
#  *** CG iteration 111, residual = 1.71e-01
#  *** CG iteration 112, residual = 1.39e-01
#  *** CG iteration 113, residual = 1.13e-01
#  *** CG iteration 114, residual = 9.16e-02
#  *** CG iteration 115, residual = 7.59e-02
#  *** CG iteration 116, residual = 6.95e-02
#  *** CG iteration 117, residual = 6.27e-02
#  *** CG iteration 118, residual = 5.46e-02
#  *** CG iteration 119, residual = 4.72e-02
#  *** CG iteration 120, residual = 3.86e-02
#  *** CG iteration 121, residual = 3.19e-02
#  *** CG iteration 122, residual = 2.88e-02
#  *** CG iteration 123, residual = 2.78e-02
#  *** CG iteration 124, residual = 2.72e-02
#  *** CG iteration 125, residual = 2.51e-02
#  *** CG iteration 126, residual = 2.46e-02
#  *** CG iteration 127, residual = 2.62e-02
#  *** CG iteration 128, residual = 2.65e-02
#  *** CG iteration 129, residual = 2.57e-02
#  *** CG iteration 130, residual = 2.53e-02
#  *** CG iteration 131, residual = 2.46e-02
#  *** CG iteration 132, residual = 2.31e-02
#  *** CG iteration 133, residual = 2.13e-02
#  *** CG iteration 134, residual = 1.95e-02
#  *** CG iteration 135, residual = 1.78e-02
#  *** CG iteration 136, residual = 1.66e-02
#  *** CG iteration 137, residual = 1.59e-02
#  *** CG iteration 138, residual = 1.52e-02
#  *** CG iteration 139, residual = 1.42e-02
#  *** CG iteration 140, residual = 1.29e-02
#  *** CG iteration 141, residual = 1.21e-02
#  *** CG iteration 142, residual = 1.13e-02
#  *** CG iteration 143, residual = 1.08e-02
#  *** CG iteration 144, residual = 1.01e-02
#  *** CG iteration 145, residual = 9.44e-03
#  *** CG iteration 146, residual = 8.89e-03
#  *** CG iteration 147, residual = 8.11e-03
#  *** CG iteration 148, residual = 7.45e-03
#  *** CG iteration 149, residual = 6.93e-03
#  *** CG iteration 150, residual = 6.17e-03
#  *** CG iteration 151, residual = 5.42e-03
#  *** CG iteration 152, residual = 4.93e-03
#  *** CG iteration 153, residual = 4.53e-03
#  *** CG iteration 154, residual = 4.15e-03
#  *** CG iteration 155, residual = 3.76e-03
#  *** CG iteration 156, residual = 3.56e-03
#  *** CG iteration 157, residual = 3.38e-03
#  *** CG iteration 158, residual = 3.18e-03
#  *** CG iteration 159, residual = 2.97e-03
#  *** CG iteration 160, residual = 2.78e-03
#  *** CG iteration 161, residual = 2.54e-03
#  *** CG iteration 162, residual = 2.43e-03
#  *** CG iteration 163, residual = 2.31e-03
#  *** CG iteration 164, residual = 2.19e-03
#  *** CG iteration 165, residual = 1.93e-03
#  *** CG iteration 166, residual = 1.66e-03
#  *** CG iteration 167, residual = 1.42e-03
#  *** CG iteration 168, residual = 1.19e-03
#  *** CG iteration 169, residual = 9.89e-04
#  *** CG iteration 170, residual = 8.74e-04
#  *** CG iteration 171, residual = 7.96e-04
#  *** CG iteration 172, residual = 7.91e-04
#  *** CG iteration 173, residual = 8.05e-04
#  *** CG iteration 174, residual = 7.95e-04
#  *** CG iteration 175, residual = 7.79e-04
#  *** CG iteration 176, residual = 7.08e-04
#  *** CG iteration 177, residual = 6.19e-04
#  *** CG iteration 178, residual = 5.62e-04
#  *** CG iteration 179, residual = 5.22e-04
#  *** CG iteration 180, residual = 4.71e-04
#  *** CG iteration 181, residual = 4.04e-04
#  *** CG iteration 182, residual = 3.50e-04
#  *** CG iteration 183, residual = 3.19e-04
#  *** CG iteration 184, residual = 3.05e-04
#  *** CG iteration 185, residual = 2.92e-04
#  *** CG iteration 186, residual = 2.74e-04
#  *** CG iteration 187, residual = 2.44e-04
#  *** CG iteration 188, residual = 2.18e-04
#  *** CG iteration 189, residual = 1.97e-04
#  *** CG iteration 190, residual = 1.76e-04
#  *** CG iteration 191, residual = 1.63e-04
#  *** CG iteration 192, residual = 1.52e-04
#  *** CG iteration 193, residual = 1.43e-04
#  *** CG iteration 194, residual = 1.31e-04
#  *** CG iteration 195, residual = 1.18e-04
#  *** CG iteration 196, residual = 1.08e-04
#  *** CG iteration 197, residual = 9.68e-05
#  *** CG iteration 198, residual = 8.75e-05
#  *** CG iteration 199, residual = 7.66e-05
#  *** CG iteration 200, residual = 6.55e-05
#  *** CG iteration 201, residual = 5.54e-05
#  *** CG iteration 202, residual = 4.94e-05
#  *** CG iteration 203, residual = 4.45e-05
#  *** CG iteration 204, residual = 3.98e-05
#  *** CG iteration 205, residual = 3.52e-05
#  *** CG iteration 206, residual = 3.15e-05
#  *** CG iteration 207, residual = 2.78e-05
#  *** CG iteration 208, residual = 2.37e-05
#  *** CG iteration 209, residual = 2.02e-05
#  *** CG iteration 210, residual = 1.72e-05
#  *** CG iteration 211, residual = 1.49e-05
#  *** CG iteration 212, residual = 1.34e-05
#  *** CG iteration 213, residual = 1.21e-05
#  *** CG iteration 214, residual = 1.10e-05
#  *** CG iteration 215, residual = 9.88e-06
#  *** CG iteration 216, residual = 9.08e-06
#  *** CG iteration 217, residual = 8.29e-06
#  *** CG iteration 218, residual = 7.48e-06
#  *** CG iteration 219, residual = 6.78e-06
#  *** CG iteration 220, residual = 6.11e-06
#  *** CG iteration 221, residual = 5.36e-06
#  *** CG iteration 222, residual = 4.60e-06
#  *** CG iteration 223, residual = 3.83e-06
#  *** CG iteration 224, residual = 3.31e-06
#  *** CG iteration 225, residual = 2.95e-06
#  *** CG iteration 226, residual = 2.76e-06
#  *** CG iteration 227, residual = 2.62e-06
#  *** CG iteration 228, residual = 2.58e-06
#  *** CG iteration 229, residual = 2.58e-06
#  *** CG iteration 230, residual = 2.59e-06
#  *** CG iteration 231, residual = 2.45e-06
#  *** CG iteration 232, residual = 2.19e-06
#  *** CG iteration 233, residual = 1.92e-06
#  *** CG iteration 234, residual = 1.68e-06
#  *** CG iteration 235, residual = 1.49e-06
#  *** CG iteration 236, residual = 1.29e-06
#  *** CG iteration 237, residual = 1.10e-06
#  *** CG iteration 238, residual = 9.18e-07
#  *** CG iteration 239, residual = 7.51e-07
#  *** CG iteration 240, residual = 6.28e-07
#  *** CG iteration 241, residual = 5.28e-07
#  *** CG iteration 242, residual = 4.51e-07

# %%
nn1 = np.array(nn1, dtype=np.int64)
tab2 = pd.DataFrame({'m':M1, 'Matrix dim':np.square(M1), 'Condition number':kappa1, 'number of CG iterations': nn1})
tab2 = tab2.style.set_caption('Ejemplo con numero de condicion no acotado')
tab2
# Out:
# <style type="text/css">
# </style>
# <table id="T_8175d">
#   <caption>Ejemplo con numero de condicion no acotado</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8175d_level0_col0" class="col_heading level0 col0" >m</th>
#       <th id="T_8175d_level0_col1" class="col_heading level0 col1" >Matrix dim</th>
#       <th id="T_8175d_level0_col2" class="col_heading level0 col2" >Condition number</th>
#       <th id="T_8175d_level0_col3" class="col_heading level0 col3" >number of CG iterations</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8175d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8175d_row0_col0" class="data row0 col0" >5</td>
#       <td id="T_8175d_row0_col1" class="data row0 col1" >25</td>
#       <td id="T_8175d_row0_col2" class="data row0 col2" >13.928203</td>
#       <td id="T_8175d_row0_col3" class="data row0 col3" >13</td>
#     </tr>
#     <tr>
#       <th id="T_8175d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8175d_row1_col0" class="data row1 col0" >10</td>
#       <td id="T_8175d_row1_col1" class="data row1 col1" >100</td>
#       <td id="T_8175d_row1_col2" class="data row1 col2" >48.374150</td>
#       <td id="T_8175d_row1_col3" class="data row1 col3" >32</td>
#     </tr>
#     <tr>
#       <th id="T_8175d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8175d_row2_col0" class="data row2 col0" >20</td>
#       <td id="T_8175d_row2_col1" class="data row2 col1" >400</td>
#       <td id="T_8175d_row2_col2" class="data row2 col2" >178.064275</td>
#       <td id="T_8175d_row2_col3" class="data row2 col3" >62</td>
#     </tr>
#     <tr>
#       <th id="T_8175d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8175d_row3_col0" class="data row3 col0" >40</td>
#       <td id="T_8175d_row3_col1" class="data row3 col1" >1600</td>
#       <td id="T_8175d_row3_col2" class="data row3 col2" >680.617070</td>
#       <td id="T_8175d_row3_col3" class="data row3 col3" >123</td>
#     </tr>
#     <tr>
#       <th id="T_8175d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8175d_row4_col0" class="data row4 col0" >80</td>
#       <td id="T_8175d_row4_col1" class="data row4 col1" >6400</td>
#       <td id="T_8175d_row4_col2" class="data row4 col2" >2658.406502</td>
#       <td id="T_8175d_row4_col3" class="data row4 col3" >242</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Example 6.15 Demmel
# El objetivo de este ejemplo es mostrar que CG puede converger mas rapido que el estimado que obtuvimos:
# \begin{equation}
# \frac{\|r_k\|_2}{\|r_0\|_2} \leq \frac{1}{T_{k}(1 + \frac{2}{\kappa-1})}
# \end{equation}
#
# Consideramos 8 sistemas lineales de dimensi\'on $n=10^4$ y el mismo n\'umero de condici\'on $\kappa \approx 4134$, sin embargo su convergencia es radicalmente diferente.
#
# El primer sistema lineal es el sistema asociado a la ecuacion de Poisson usando diferencias finitas
#
# Tenemos 7 sistemas lineales diagonales de la forma $D_{i} x = b$, donde cada $D_i$ tiene mismo numero de condicion que la matriz $A$. Cada $D_i$ se construye tal que sus $m_i$ valores propios mas pequenos y sus $m_i$ valores propios mas grandes coinciden con los correspondientes valores propios de la matriz $A$. El resto de los $n-2m_i$ valores propios de $D_i$ se toman como el la media geometrica de los mayores y menores valores propios. Asi cada $D_i$ tiene solo $2m_i+1$ valores propios distintos.
#
# Tambien graficamos la cota del error relativo
# \begin{equation}
#  \frac{1}{T_{k}(1 + \frac{2}{\kappa-1})}
# \end{equation}

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.sparse import csr_matrix
from scipy.sparse.linalg import cg, eigs
from scipy.stats.mstats import gmean
from scipy.special import eval_chebyt
import pandas as pd

# %% [markdown]
# Calculamos la matriz de diferencias finitas asociada a la ecuacion de Poisson

# %%
n = 100
# one dimensional finite difference matrix
A1d = np.diag(2*np.ones(n)) + np.diag(-1*np.ones(n-1),-1)+ np.diag(-1*np.ones(n-1),1)

# two dimensional finite difference matrix
A2d = np.kron(np.eye(n),A1d) + np.kron(A1d, np.eye(n))

A = csr_matrix(A2d)
# random vector as right hand side
# b = np.random.rand(n**2)
b = np.random.normal(0, 1, n**2)

# %% [markdown]
# Calculamos los valores propios de esta matriz.

# %%
# Eigenvalues and condition number
lambdas = [2*(1.0-np.cos(np.pi*j/(n+1))) for j in range(1,n+1)]
kappa = lambdas[-1]/lambdas[0]

l2d = np.zeros(n**2)
k = 0
for i in range(0,n):
    for j in range(0, n):
        l2d[k] = lambdas[i]+lambdas[j]
        k = k+1
l2d = np.sort(l2d)
lamSM,_ = eigs(A,k=3,which='SM')
lamLM,_ = eigs(A,k=3,which='LM')
print(l2d)
print(lamSM, lamLM)
# Out:
# [1.93487083e-03 4.83624115e-03 4.83624115e-03 ... 7.99516376e+00
#  7.99516376e+00 7.99806513e+00]
# [0.00193487+0.j 0.00483624+0.j 0.00483624+0.j] [7.99806513+0.j 7.99516376+0.j 7.99516376+0.j]

# %%
class cg_counter(object):
    def __init__(self, A, b, disp=True):
        self._disp = disp
        self.niter = 0
        self.A = A
        self.b = b
        self.rk = []
    def __call__(self, xk=None):
        self.niter += 1
        if self._disp:
            rk = self.b-self.A.dot(xk) 
            rhok = np.linalg.norm(rk)
            # print('iter %3i\trk = %s' % (self.niter, str(rhok)))      
            self.rk.append(rk)


print( )
# Out:
# [1.93487083e-03 4.83624115e-03 4.83624115e-03 7.73761147e-03
#  9.66873948e-03 7.99033126e+00 7.99226239e+00 7.99516376e+00
#  7.99516376e+00 7.99806513e+00]

# %%
m1 = 1; dm1 = 1+2*m1
gm1 = gmean(np.concatenate((l2d[:m1],  l2d[-m1:])))
D1 = np.diag(np.hstack((l2d[:m1],gm1*np.ones(n**2-2*m1), l2d[-m1:]) ))
print("geometric mean for D_1 :", gm1)
D1sp = csr_matrix(D1)

m2 = 5; dm2 = 1+2*m2
gm2 = gmean(np.concatenate((l2d[:m2],  l2d[-m2:])))
D2 = np.diag(np.hstack((l2d[:m2],gm2*np.ones(n**2-2*m2), l2d[-m2:]) ))
print("geometric mean for D_2 :", gm2)
D2sp = csr_matrix(D2)

m3 = 20; dm3 = 1+2*m3
gm3 = gmean(np.concatenate((l2d[:m3],  l2d[-m3:])))
D3 = np.diag(np.hstack((l2d[:m3],gm3*np.ones(n**2-2*m3), l2d[-m3:]) ))
print("geometric mean for D_3 :", gm3)
D3sp = csr_matrix(D3)

m4 = 40; dm4 = 1+2*m4
gm4 = gmean(np.concatenate((l2d[:m4],  l2d[-m4:])))
D4 = np.diag(np.hstack((l2d[:m4],gm4*np.ones(n**2-2*m4), l2d[-m4:]) ))
print("geometric mean for D_4 :", gm4)
D4sp = csr_matrix(D4)

m5 = 100; dm5 = 1+2*m5
gm5 = gmean(np.concatenate((l2d[:m5],  l2d[-m5:])))
D5 = np.diag(np.hstack((l2d[:m5],gm5*np.ones(n**2-2*m5), l2d[-m5:]) ))
print("geometric mean for D_5 :", gm5)
D5sp = csr_matrix(D5)

m6 = 200; dm6 = 1+2*m6
gm6 = gmean(np.concatenate((l2d[:m6],  l2d[-m6:])))
D6 = np.diag(np.hstack((l2d[:m6],gm6*np.ones(n**2-2*m6), l2d[-m6:]) ))
print("geometric mean for D_6 :", gm6)
D6sp = csr_matrix(D6)

m7 = 2500; dm7 = 1+2*m7
gm7 = gmean(np.concatenate((l2d[:m7],  l2d[-m7:])))
D7 = np.diag(np.hstack((l2d[:m7],gm7*np.ones(n**2-2*m7), l2d[-m7:]) ))
print("geometric mean for D_7 :", gm7)
D7sp = csr_matrix(D7)
# Out:
# geometric mean for D_1 : 0.12439944907934594
# geometric mean for D_2 : 0.20153565128422213
# geometric mean for D_3 : 0.33403981346244566
# geometric mean for D_4 : 0.4451384688483489
# geometric mean for D_5 : 0.6637394245148277
# geometric mean for D_6 : 0.9061185551904
# geometric mean for D_7 : 2.651597855454122

# %%
counter_A = cg_counter(A, b)
x, info = cg(A, b, tol=10**(-13), maxiter=500, callback=counter_A)

counter_D1 = cg_counter(D1sp, b)
xD1, info = cg(D1sp, b, tol=10**(-13), maxiter=200, callback=counter_D1)

counter_D2 = cg_counter(D2sp, b)
xD2, info = cg(D2sp, b, tol=10**(-13), maxiter=200, callback=counter_D2)

counter_D3 = cg_counter(D3sp, b)
xD3, info = cg(D3sp, b, tol=10**(-13), maxiter=200, callback=counter_D3)

counter_D4 = cg_counter(D4sp, b)
xD4, info = cg(D4sp, b, tol=10**(-13), maxiter=200, callback=counter_D4)

counter_D5 = cg_counter(D5sp, b)
xD5, info = cg(D5sp, b, tol=10**(-13), maxiter=200, callback=counter_D5)

counter_D6 = cg_counter(D6sp, b)
xD6, info = cg(D6sp, b, tol=10**(-13), maxiter=200, callback=counter_D6)

counter_D7 = cg_counter(D7sp, b)
xD7, info = cg(D7sp, b, tol=10**(-13), maxiter=500, callback=counter_D7)

# %%
i
df = pd.DataFrame({'Matriz': ['A','D1','D2','D3','D4','D5','D6','D7'], 
                   'Num. val.p. distintos':[n**2, dm1,dm2,dm3,dm4,dm5,dm6,dm7],
                   'num. CG. iteraciones': [len(counter_A.rk), len(counter_D1.rk),len(counter_D2.rk),len(counter_D3.rk),len(counter_D4.rk),len(counter_D5.rk),len(counter_D6.rk),len(counter_D7.rk)]})
df
# Out:
#   Matriz  Num. val.p. distintos  num. CG. iteraciones
# 0      A                  10000                   405
# 1     D1                      3                     4
# 2     D2                     11                    11
# 3     D3                     41                    26
# 4     D4                     81                    50
# 5     D5                    201                    98
# 6     D6                    401                   142
# 7     D7                   5001                   378

# %%
def rkoverr0(rk):
    return [(np.linalg.norm(rk[i]))/(np.linalg.norm(b)) for i in range(len(rk)) ]
fig, ax = plt.subplots(1,1, figsize=(10,10))

ax.semilogy(range(min(len(counter_A.rk),200))  , rkoverr0(counter_A.rk)[:200]  , label='A')
ax.semilogy(range(len(counter_D1.rk)) , rkoverr0(counter_D1.rk) , label='D1')
ax.semilogy(range(len(counter_D2.rk)) , rkoverr0(counter_D2.rk) , label='D2')
ax.semilogy(range(len(counter_D3.rk)) , rkoverr0(counter_D3.rk) , label='D3')
ax.semilogy(range(len(counter_D4.rk)) , rkoverr0(counter_D4.rk) , label='D4')
ax.semilogy(range(len(counter_D5.rk)) , rkoverr0(counter_D5.rk) , label='D5')
ax.semilogy(range(len(counter_D6.rk)) , rkoverr0(counter_D6.rk) , label='D6')
ax.semilogy(range(min(len(counter_D7.rk),200)) , rkoverr0(counter_D7.rk)[:200] , label='D7')

ax.semilogy(range(200), [1.0/eval_chebyt(n, 1+2.0/(kappa-1)) for n in range(200)], label='1/T_k' )
ax.legend(loc=4,prop={'size': 18})
plt.show()

# %% [markdown]
# ### Observaciones
# - Si los valores propios mas pequenos y mas grandes de la matriz $A$ son pocos en numero (o estan clusterizados) entonces CG convergera mucho mas rapido que el estimado del analisis, el cual solo se basa en el numero de condicion de la matriz $A$.
# - El comportamiento de CG en aritmetica de punto flotante puede ser significativamente distinto que su comportamiento en aritmetica exacta. Vemos esto ya que observamos que el numero de iteraciones requeridas para converger difiere del numero de valores propios distintos cuando sabemos que estos deberian ser identicos.
